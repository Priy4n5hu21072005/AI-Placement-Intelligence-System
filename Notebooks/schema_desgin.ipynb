# %%
final_columns = [
    "cgpa",
    "college_tier",
    "branch",
    "internship_count",
    "projects_count",
    "skills_score",
    "communication_score",
    "certifications",
    "dsa_score",
    "placed"
]
